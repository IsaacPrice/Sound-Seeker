# %%
import pandas as pd
data = pd.read_csv("AlbumRankings.csv")
data.head()
# Out:
#            Midnights  Unnamed: 1  8.38      Utopia  Unnamed: 4  8.63  \
# 0                NaN         NaN   NaN         NaN         NaN   NaN
# 1      Lavender Haze        11.0   NaN      HYEANA        11.0   NaN
# 2             Maroon        10.0   NaN   THANK GOD         8.5   NaN
# 3          Anti-Hero        10.0   NaN  MODERN JAM         4.5   NaN
# 4  Snow On The Beach         8.5   NaN     MY EYES         8.0   NaN
#
#           Pink Tape  Unnamed: 7 6.99            Her Loss  Unnamed: 10  9.53  \
# 0               NaN         NaN  NaN                 NaN          NaN   NaN
# 1  Flooded The Face        6.50  NaN           Rich Flex         9.25   NaN
# 2     Suicide Doors        6.75  NaN  Major Distribution        10.00   NaN
# 3  Aye (ft. Travis)        7.00  NaN               On BS        10.00   NaN
# 4          Crush Em        7.75  NaN     BackOutsideBoyz         9.00   NaN
#
#        808s & Heartbreak  Unnamed: 13 7.00
# 0                    NaN          NaN  NaN
# ...

# %% [markdown]
# 1. Take out the unneeded columns
# 2. Take out the first row
# 3. Seperate the columns into the pairs with the name and rating
# 4. Clean each new dataframe
# 5. Combine and write to a new csv

# %%
# Take out the unneeded columns
keep = ['Midnights', 'Unnamed: 1', 'Utopia', 'Unnamed: 4', 'Pink Tape', 'Unnamed: 7', 'Her Loss', 'Unnamed: 10', '808s & Heartbreak', 'Unnamed: 13']
data = data[keep]
data
# Out:
#             Midnights  Unnamed: 1                Utopia  Unnamed: 4  \
# 0                 NaN         NaN                   NaN         NaN
# 1       Lavender Haze        11.0                HYEANA       11.00
# 2              Maroon        10.0             THANK GOD        8.50
# 3           Anti-Hero        10.0            MODERN JAM        4.50
# 4   Snow On The Beach         8.5               MY EYES        8.00
# ..                ...         ...                   ...         ...
# 70                NaN         NaN         get him back!        8.00
# 71                NaN         NaN  love is embarrassing        9.50
# 72                NaN         NaN            the grudge        9.25
# 73                NaN         NaN    pretty isnt pretty        9.25
# 74                NaN         NaN         teenage dream       10.00
#
#            Pink Tape  Unnamed: 7            Her Loss  Unnamed: 10  \
# 0                NaN         NaN                 NaN          NaN
# ...

# %%
# Take out the first row
data = data.drop(0, axis='index')
data.head()
# Out:
#                  Midnights  Unnamed: 1         Utopia  Unnamed: 4  \
# 1            Lavender Haze        11.0         HYEANA        11.0
# 2                   Maroon        10.0      THANK GOD         8.5
# 3                Anti-Hero        10.0     MODERN JAM         4.5
# 4        Snow On The Beach         8.5        MY EYES         8.0
# 5  You're On Your Own, Kid         9.0  GOD'S COUNTRY         7.0
#
#           Pink Tape  Unnamed: 7            Her Loss  Unnamed: 10  \
# 1  Flooded The Face        6.50           Rich Flex         9.25
# 2     Suicide Doors        6.75  Major Distribution        10.00
# 3  Aye (ft. Travis)        7.00               On BS        10.00
# 4          Crush Em        7.75     BackOutsideBoyz         9.00
# 5             Amped        3.50  Privilaged Rappers        10.00
#
#        808s & Heartbreak  Unnamed: 13
# 1           Say You Will          9.0
# 2  Welcome to Heartbreak          8.0
# 3              Heartless          8.0
# ...

# %%
# Seperate the columns into the pairs with the name and rating
col1 = data[['Midnights', 'Unnamed: 1']]
col2 = data[['Utopia', 'Unnamed: 4']]
col3 = data[['Pink Tape', 'Unnamed: 7']]
col4 = data[['Her Loss', 'Unnamed: 10']]
col5 = data[['808s & Heartbreak', 'Unnamed: 13']]

# %%
# Clean each new dataframe
col1.dropna(axis='index', inplace=True)
col2.dropna(axis='index', inplace=True)
col3.dropna(axis='index', inplace=True)
col4.dropna(axis='index', inplace=True)
col5.dropna(axis='index', inplace=True)
col1 = col1.rename(columns={'Midnights': 'song', 'Unnamed: 1' : 'value'})
col2 = col2.rename(columns={'Utopia': 'song', 'Unnamed: 4' : 'value'})
col3 = col3.rename(columns={'Pink Tape': 'song', 'Unnamed: 7' : 'value'})
col4 = col4.rename(columns={'Her Loss': 'song', 'Unnamed: 10' : 'value'})
col5 = col5.rename(columns={'808s & Heartbreak': 'song', 'Unnamed: 13' : 'value'})
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_22012\1319713600.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col1.dropna(axis='index', inplace=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_22012\1319713600.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col2.dropna(axis='index', inplace=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_22012\1319713600.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
# Combine and write to a csv
new_data = pd.concat([col1, col2, col3, col4, col5], axis='index', join='inner')
new_data.sort_index()
new_data.head(40)
# Out:
#                        song  value
# 1             Lavender Haze   11.0
# 2                    Maroon   10.0
# 3                 Anti-Hero   10.0
# 4         Snow On The Beach    8.5
# 5   You're On Your Own, Kid    9.0
# 6             Midnight Rain    7.0
# 7              Question...?    7.0
# 8              Vigilante S*    5.5
# 9                 Bejeweled   10.0
# 10                Labyrinth    6.0
# 11                    Karma   10.0
# 12            Sweet Nothing    6.0
# 13               Mastermind    9.0
# 16             Good Morning   10.0
# 17                 Champion   11.0
# 18                 Stronger    9.0
# 19                 I Wonder   11.0
# 20                Good Life   10.0
# 21    Can't Tell Me Nothing    9.0
# 22              Barry Bonds    7.0
# 23      Drunk and Hot Girls    7.0
# 24          Flashing Lights   11.0
# 25          Everything I Am   10.0
# 26                The Glory   10.0
# 27              Homecoming    10.0
# 28              Big Brother   10.0
# ...

# %%
# Write to a csv
new_data.to_csv("Cleaned.csv")
